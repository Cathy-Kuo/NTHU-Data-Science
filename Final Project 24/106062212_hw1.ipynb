# %%
import requests
from bs4 import BeautifulSoup
import json
import re

# %%
# f = open("input_hw1.txt")
# lines = f.readlines()
output = open("106062212_hw1_output.txt",'w+', encoding='UTF-8') 
addr = 'https://search.taobao.tw/catalog/?q=%E8%83%8C%E5%BF%83%E5%A5%B3&_keyori=ss&from=input'
r = requests.get(addr)
soup = BeautifulSoup(r.text,"html.parser")
# print(soup)

# %%
pageConfig = soup.find('script', text=re.compile('window.pageData'))
pagecon = pageConfig.string[16:len(pageConfig.string)]
data_json = json.loads(pagecon)
# print(data_json)

# %%
for i in range(1):
#     print(data_json['mods']['listItems'][i]['name'])
    sour = 'http:'
    addr = sour + data_json['mods']['listItems'][4]['productUrl']
    print(addr)
    r = requests.get(addr)
    soup = BeautifulSoup(r.text,"html.parser")
    print(soup)
    title = soup.find('title')
#     print(title)
# Out:
# http://item.taobao.tw/products/bra-tlavietb0036-i88265485-s962725590.html?urlFlag=true&search=1
#
# <!DOCTYPE HTML>
#
# <html xmlns:wormhole="http://www.w3.org/1999/xhtml">
# <head>
# <title>背心《免穿內衣》BRA T帶胸墊升級版打底衫內衣莫代爾木漿棉無鋼圈胸罩內衣女上衣【LaVie洛薇】TB0036 | 淘寶台灣</title>
# <meta content="在淘寶 Taiwan 線上購買 背心《免穿內衣》BRA T帶胸墊升級版打底衫內衣莫代爾木漿棉無鋼圈胸罩內衣女上衣【LaVie洛薇】TB0036。 背心和細肩帶背心 全面享折扣價和銷售促銷。 免運費。" name="description"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="a2w01" name="data-spm"/>
# <meta content="index,follow" name="robots"/>
# <link href="//g-ovs.alicdn.com/tmg-fe/assets/dpl-tmall-tw/4.0.0/next.min.css" rel="stylesheet"/>
# <link href="https://img-ovs.alicdn.com/tfs/TB1d9TCghD1gK0jSZFyXXciOVXa-16-16.png" rel="shortcut icon"/>
# <link href="//g-ovs.alicdn.com/tmg-fe/pdp/1.0.21/pc.css" rel="stylesheet"/>
# <link href="https://item.taobao.tw/products/bra-tlavietb0036-i88265485.html" rel="canonical"/>
# ...

# %%
buy = soup.find_all('script')[20]
buy = buy.string[1328:len(buy.string)-331]
print(buy)
# Out:
# {"data":{"root":{"fields":{"seller":{"chatUrl":"https://h5.m.taobao.tw/chat?brandId=6564500","hideAllMetrics":false,"imEnable":true,"imUserId":"2000001324024","levelDegree":4,"levelType":1,"name":"LaVie洛薇美物","newSeller":false,"percentRate":"100%","rate":1,"rateLevel":3,"sellerId":"2000001324024","shopId":5201,"size":1,"time":7,"type":"4","unit":"個月","url":"https://shop.taobao.tw/shop/lavie/?itemId=88265485&channelSource=pdp"},"flashSale":{},"specifications":{"962725590":{"boxContent":"1","features":{"品牌":"自有品牌","SKU":"88265485_TW-962725590","袖子":"無袖","保固類型":"無保修"}},"962725598":{"boxContent":"1","features":{"品牌":"自有品牌","SKU":"88265485_TW-962725598","袖子":"無袖","保固類型":"無保修"}},"962725597":{"boxContent":"1","features":{"品牌":"自有品牌","SKU":"88265485_TW-962725597","袖子":"無袖","保固類型":"無保修"}},"962725596":{"boxContent":"1","features":{"品牌":"自有品牌","SKU":"88265485_TW-962725596","袖子":"無袖","保固類型":"無保修"}},"962725595":{"boxContent":"1","features":{"品牌":"自有品牌","SKU":"88265485_TW-962725595","袖子":"無袖","保固類型
# ...

# %%
buy_json = json.loads(buy)
print(buy_json['data']['root']['fields'])
# Out:
# {'seller': {'chatUrl': 'https://h5.m.taobao.tw/chat?brandId=6564500', 'hideAllMetrics': False, 'imEnable': True, 'imUserId': '2000001324024', 'levelDegree': 4, 'levelType': 1, 'name': 'LaVie洛薇美物', 'newSeller': False, 'percentRate': '100%', 'rate': 1, 'rateLevel': 3, 'sellerId': '2000001324024', 'shopId': 5201, 'size': 1, 'time': 7, 'type': '4', 'unit': '個月', 'url': 'https://shop.taobao.tw/shop/lavie/?itemId=88265485&channelSource=pdp'}, 'flashSale': {}, 'specifications': {'962725590': {'boxContent': '1', 'features': {'品牌': '自有品牌', 'SKU': '88265485_TW-962725590', '袖子': '無袖', '保固類型': '無保修'}}, '962725598': {'boxContent': '1', 'features': {'品牌': '自有品牌', 'SKU': '88265485_TW-962725598', '袖子': '無袖', '保固類型': '無保修'}}, '962725597': {'boxContent': '1', 'features': {'品牌': '自有品牌', 'SKU': '88265485_TW-962725597', '袖子': '無袖', '保固類型': '無保修'}}, '962725596': {'boxContent': '1', 'features': {'品牌': '自有品牌', 'SKU': '88265485_TW-962725596', '袖子': '無袖', '保固類型': '無保修'}}, '962725595': {'boxContent': '1', 'fea
# ...

# %%
print(buy_json['data']['root']['fields']['product'])
# Out:
# {'brand': {'name': '自有品牌', 'suggestion': '更多 自有品牌 的 上衣', 'suggestionUrl': 'http://search.taobao.tw/shop-clothing-t-shirts-tops/no-brand/', 'url': 'http://search.taobao.tw/no-brand/'}, 'desc': '<span style="font-family: simhei;"></span><div style="width: 100.0%;margin: 0;padding: 8.0px 0;white-space: pre-wrap;"><div style="width: 100.0%;display: block;"><img src="https://my-live-01.slatic.net/p/5cba2276a01be71155d5e8580f408030.jpg" style="width: 100.0%;display: block;"/></div></div><div style="width: 100.0%;margin: 0;padding: 8.0px 0;white-space: pre-wrap;"><div style="width: 100.0%;display: block;"><img src="https://my-live-01.slatic.net/p/1739ed3f28e66bc25073e93161b47c71.jpg" style="width: 100.0%;display: block;"/></div></div><div style="width: 100.0%;margin: 0;padding: 8.0px 0;white-space: pre-wrap;"><div style="width: 100.0%;display: block;"><img src="https://my-live-01.slatic.net/p/8e232d2a8ffafa3011df53b8f428c4af.jpg" style="width: 100.0%;display: block;"/></div></div><div style
# ...

# %%
print(len(buy_json['data']['root']['fields']['product']))
# Out:
# 8

# %%
print(buy_json['data']['root']['fields']['product']['middleText'][2])
print(len(buy_json['data']['root']['fields']['product']['middleText']))
# Out:
#
# 6

# %%
print(buy_json['data']['root']['fields']['product']['rating'])
# Out:
# {'score': 0.0, 'total': 0}

# %%
print(buy_json['data']['root']['fields']['product']['middleText'][0:2])
#sellnum
print(buy_json['data']['root']['fields']['price']['962725590']['salePrice']['value'])
#price
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-c28c1675e265> in <module>
# ----> 1 print(buy_json['data']['root']['fields']['product']['middleText'][0:2])
#       2 #sellnum
#       3 print(buy_json['data']['root']['fields']['price']['962725590']['salePrice']['value'])
#       4 #price
#
# KeyError: 'middleText'

# %%
print(buy_json['data']['root']['fields']['product'])
# Out:
# {'brand': {'name': '自有品牌', 'suggestion': '更多 自有品牌 的 上衣', 'suggestionUrl': 'http://search.taobao.tw/shop-clothing-t-shirts-tops/no-brand/', 'url': 'http://search.taobao.tw/no-brand/'}, 'desc': '<br/> <p style="text-align: center;">\xa0</p> <p style="text-align: center;"> <span style="font-size: 16.0px;">尺寸: 胸圍 64-84 cm 衣長 52 cm</span><span style="font-size: 10.0pt;">\xa0</span></p> <p style="text-align: center;"><img style="max-width: 750.0px;" align="absmiddle" src="https://my-live-01.slatic.net/p/72ecd1cdf7b7ba079787de4202709e59.jpg"/></p> <p style="text-align: center;">\xa0</p> <p style="text-align: center;">\xa0</p> <p style="text-align: center;"><img style="max-width: 750.0px;" align="absmiddle" src="https://my-live-01.slatic.net/p/e5c07d3d82221bebb4a3f85411de7b20.jpg"/></p> <p style="text-align: center;">\xa0</p> <p style="text-align: center;">\xa0</p> <p style="text-align: center;"><img style="max-width: 750.0px;" align="absmiddle" src="https://my-live-01.slatic.net/p/29d71fb3b
# ...
