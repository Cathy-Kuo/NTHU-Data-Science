# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
ua = UserAgent()
headers = {
    'User-Agent': 'Googlebot',
    'From': 'myth594@gmail.com'
}
items_a = []
rate_a = []
num_rate_a = []
num_sold_a = []
price_a = []
for i in range(10):
    print(i)
    url = 'https://shopee.tw/search?keyword=帽子&page='+str(i)+'&sortBy=sales'
    r = requests.get(url,headers=headers,allow_redirects=False)
    soup = BeautifulSoup(r.text, 'html.parser')
    url_list = soup.find_all("a")
    for j in range(13,53,1):
        try:
            url2 = 'https://shopee.tw'+url_list[j]['href']
            r = requests.get(url2,headers=headers,allow_redirects=False)
            soup = BeautifulSoup(r.text, 'html.parser')
            items = soup.find('div','qaNIZv').text
            rate = soup.find('div','_3Oj5_n _2z6cUg').text
            num_rate = soup.find_all('div','_3Oj5_n')[1].text
            num_sold = soup.find('div','_22sp0A').text
            price = soup.find('div','_3n5NQx').text
            items_a.append(items)
            rate_a.append(rate)
            num_rate_a.append(num_rate)
            num_sold_a.append(num_sold)
            price_a.append(price)
        except:
            print('error')
# Out:
# 0
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 1
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 2
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 3
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 4
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 5
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 6
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 7
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 8
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 9
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error

# %%
import pandas as pd
df = {'item':items_a,'rate':rate_a,'num_rate':num_rate_a,'num_sold':num_sold_a,'price':price_a}
df = pd.DataFrame(df)
df.to_csv("shopee帽子.csv")

# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
ua = UserAgent()
headers = {
    'User-Agent': 'Googlebot',
    'From': 'myth594@gmail.com'
}
items_a = []
rate_a = []
num_rate_a = []
num_sold_a = []
price_a = []
for i in range(45):
    print(i)
    url = 'https://shopee.tw/search?keyword=吸塵器&page='+str(i)+'&sortBy=sales'
    r = requests.get(url,headers=headers,allow_redirects=False)
    soup = BeautifulSoup(r.text, 'html.parser')
    url_list = soup.find_all("a")
    for j in range(13,53,1):
        try:
            url2 = 'https://shopee.tw'+url_list[j]['href']
            r = requests.get(url2,headers=headers,allow_redirects=False)
            soup = BeautifulSoup(r.text, 'html.parser')
            items = soup.find('div','qaNIZv').text
            rate = soup.find('div','_3Oj5_n _2z6cUg').text
            num_rate = soup.find_all('div','_3Oj5_n')[1].text
            num_sold = soup.find('div','_22sp0A').text
            price = soup.find('div','_3n5NQx').text
            items_a.append(items)
            rate_a.append(rate)
            num_rate_a.append(num_rate)
            num_sold_a.append(num_sold)
            price_a.append(price)
        except:
            print('error')
# Out:
# 0
# error
# error
# error
# error
# error
# error
# 1
# error
# 2
# 3
# error
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# error
# error
# 13
# error
# 14
# 15
# 16
# 17
# 18
# 19
# error
# error
# 20
# error
# error
# error
# 21
# error
# error
# error
# 22
# error
# error
# error
# error
# error
# error
# error
# 23
# error
# error
# error
# 24
# error
# error
# error
# error
# 25
# error
# 26
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 27
# error
# error
# error
# error
# 28
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 29
# error
# error
# error
# error
# error
# error
# error
# 30
# error
# error
# error
# error
# error
# error
# 31
# error
# error
# error
# error
# error
# error
# error
# 32
# error
# error
# error
# error
# error
# 33
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 34
# error
# error
# error
# error
# 35
# error
# 36
# error
# error
# error
# error
# error
# error
# 37
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 38
# error
# 39
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 40
# error
# error
# 41
# error
# error
# 42
# error
# error
# error
# error
# error
# error
# error
# 43
# error
# error
# error
# error
# error
# error
# 44
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error

# %%
import pandas as pd
df = {'item':items_a,'rate':rate_a,'num_rate':num_rate_a,'num_sold':num_sold_a,'price':price_a}
df = pd.DataFrame(df)
df.to_csv("shopee吸塵器.csv")

# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
ua = UserAgent()
headers = {
    'User-Agent': 'Googlebot',
    'From': 'myth594@gmail.com'
}
items_a = []
rate_a = []
num_rate_a = []
num_sold_a = []
price_a = []
for i in range(11):
    print(i)
    url = 'https://shopee.tw/search?keyword=飲水機&page='+str(i)+'&sortBy=sales'
    r = requests.get(url,headers=headers,allow_redirects=False)
    soup = BeautifulSoup(r.text, 'html.parser')
    url_list = soup.find_all("a")
    for j in range(13,53,1):
        try:
            url2 = 'https://shopee.tw'+url_list[j]['href']
            r = requests.get(url2,headers=headers,allow_redirects=False)
            soup = BeautifulSoup(r.text, 'html.parser')
            items = soup.find('div','qaNIZv').text
            rate = soup.find('div','_3Oj5_n _2z6cUg').text
            num_rate = soup.find_all('div','_3Oj5_n')[1].text
            num_sold = soup.find('div','_22sp0A').text
            price = soup.find('div','_3n5NQx').text
            items_a.append(items)
            rate_a.append(rate)
            num_rate_a.append(num_rate)
            num_sold_a.append(num_sold)
            price_a.append(price)
        except:
            print('error')
# Out:
# 0
# error
# 1
# 2
# 3
# 4
# error
# 5
# error
# error
# 6
# error
# error
# error
# error
# error
# error
# error
# error
# 7
# error
# error
# error
# error
# error
# 8
# error
# error
# error
# error
# error
# error
# error
# 9
# error
# error
# error
# error
# error
# error
# 10
# error
# error
# error
# error
# error
# error
# error
# error
# error

# %%
import pandas as pd
df = {'item':items_a,'rate':rate_a,'num_rate':num_rate_a,'num_sold':num_sold_a,'price':price_a}
df = pd.DataFrame(df)
df.to_csv("shopee飲水機.csv")
