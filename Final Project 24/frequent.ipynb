# %%
import pandas as pd 
import glob 
import jieba

# %%
df_ruten_dust = pd.read_csv('家電_ruten/露天_吸塵器.csv',index_col=0)
df_ruten_juice = pd.read_csv('家電_ruten/露天_果汁機.csv',index_col=0)
df_ruten_fry = pd.read_csv('家電_ruten/露天_氣炸鍋.csv',index_col=0)
df_ruten_oven = pd.read_csv('家電_ruten/露天_烤箱.csv',index_col=0)
df_ruten_water = pd.read_csv('家電_ruten/露天_飲水機.csv',index_col=0)
df_ruten_wave = pd.read_csv('家電_ruten/露天_微波爐.csv',index_col=0)
df_ruten_wind = pd.read_csv('家電_ruten/露天_電風扇.csv',index_col=0)
df_ruten_stove = pd.read_csv('家電_ruten/露天_電磁爐.csv',index_col=0)
df_ruten_pot = pd.read_csv('家電_ruten/露天_電鍋.csv',index_col=0)
df_ruten_weight = pd.read_csv('家電_ruten/露天_體重計.csv',index_col=0)
df_ruten_elec = {}
df_ruten_elec['dust'] = df_ruten_dust
df_ruten_elec['juice'] = df_ruten_juice
df_ruten_elec['fry'] = df_ruten_fry
df_ruten_elec['oven'] = df_ruten_oven
df_ruten_elec['water'] = df_ruten_water
df_ruten_elec['wave'] = df_ruten_wave
df_ruten_elec['wind'] = df_ruten_wind
df_ruten_elec['stove'] = df_ruten_stove
df_ruten_elec['pot'] = df_ruten_pot
df_ruten_elec['weight'] = df_ruten_weight

df_ruten_elec1 = {}
df_ruten_elec1['dust'] = df_ruten_dust[0:100]
df_ruten_elec1['juice'] = df_ruten_juice[0:100]
df_ruten_elec1['fry'] = df_ruten_fry[0:100]
df_ruten_elec1['oven'] = df_ruten_oven[0:100]
df_ruten_elec1['water'] = df_ruten_water[0:100]
df_ruten_elec1['wave'] = df_ruten_wave[0:100]
df_ruten_elec1['wind'] = df_ruten_wind[0:100]
df_ruten_elec1['stove'] = df_ruten_stove[0:100]
df_ruten_elec1['pot'] = df_ruten_pot[0:100]
df_ruten_elec1['weight'] = df_ruten_weight[0:100]

# %%
df_shopee_dust = pd.read_csv('家電_shopee/shopee吸塵器.csv',index_col=0)
df_shopee_juice = pd.read_csv('家電_shopee/shopee果汁機.csv',index_col=0)
df_shopee_fry = pd.read_csv('家電_shopee/shopee氣炸鍋.csv',index_col=0)
df_shopee_oven = pd.read_csv('家電_shopee/shopee烤箱.csv',index_col=0)
df_shopee_water = pd.read_csv('家電_shopee/shopee飲水機.csv',index_col=0)
df_shopee_wave = pd.read_csv('家電_shopee/shopee微波爐.csv',index_col=0)
df_shopee_wind = pd.read_csv('家電_shopee/shopee電風扇.csv',index_col=0)
df_shopee_stove = pd.read_csv('家電_shopee/shopee電磁爐.csv',index_col=0)
df_shopee_pot = pd.read_csv('家電_shopee/shopee電鍋.csv',index_col=0)
df_shopee_weight = pd.read_csv('家電_shopee/shopee體重計.csv',index_col=0)
df_shopee_elec = {}
df_shopee_elec['dust'] = df_shopee_dust
df_shopee_elec['juice'] = df_shopee_juice
df_shopee_elec['fry'] = df_shopee_fry
df_shopee_elec['oven'] = df_shopee_oven
df_shopee_elec['water'] = df_shopee_water
df_shopee_elec['wave'] = df_shopee_wave
df_shopee_elec['wind'] = df_shopee_wind
df_shopee_elec['stove'] = df_shopee_stove
df_shopee_elec['pot'] = df_shopee_pot
df_shopee_elec['weight'] = df_shopee_weight

df_shopee_elec1 = {}
df_shopee_elec1['dust'] = df_shopee_dust[0:100]
df_shopee_elec1['juice'] = df_shopee_juice[0:100]
df_shopee_elec1['fry'] = df_shopee_fry[0:100]
df_shopee_elec1['oven'] = df_shopee_oven[0:100]
df_shopee_elec1['water'] = df_shopee_water[0:100]
df_shopee_elec1['wave'] = df_shopee_wave[0:100]
df_shopee_elec1['wind'] = df_shopee_wind[0:100]
df_shopee_elec1['stove'] = df_shopee_stove[0:100]
df_shopee_elec1['pot'] = df_shopee_pot[0:100]
df_shopee_elec1['weight'] = df_shopee_weight[0:100]

# %%
df_ruten_coat1 = pd.read_csv('clothes_ruten/露天外套女.csv',index_col=0)
df_ruten_coat2 = pd.read_csv('clothes_ruten/露天外套男.csv',index_col=0)
df_ruten_long1 = pd.read_csv('clothes_ruten/露天長袖女.csv',index_col=0)
df_ruten_long2 = pd.read_csv('clothes_ruten/露天長袖男.csv',index_col=0)
df_ruten_pants1 = pd.read_csv('clothes_ruten/露天長褲女.csv',index_col=0)
df_ruten_pants2 = pd.read_csv('clothes_ruten/露天長褲男.csv',index_col=0)
df_ruten_vest1 = pd.read_csv('clothes_ruten/露天背心女.csv',index_col=0)
df_ruten_vest2 = pd.read_csv('clothes_ruten/露天背心男.csv',index_col=0)
df_ruten_short1 = pd.read_csv('clothes_ruten/露天短袖女.csv',index_col=0)
df_ruten_short2 = pd.read_csv('clothes_ruten/露天短袖男.csv',index_col=0)
df_ruten_shorts1 = pd.read_csv('clothes_ruten/露天短褲女.csv',index_col=0)
df_ruten_shorts2 = pd.read_csv('clothes_ruten/露天短褲男.csv',index_col=0)
df_ruten_clothes = {}
df_ruten_clothes['coat1'] = df_ruten_coat1
df_ruten_clothes['coat2'] = df_ruten_coat2
df_ruten_clothes['long1'] = df_ruten_long1
df_ruten_clothes['long2'] = df_ruten_long2
df_ruten_clothes['pants1'] = df_ruten_pants1
df_ruten_clothes['pants2'] = df_ruten_pants2
df_ruten_clothes['vest1'] = df_ruten_vest1
df_ruten_clothes['vest2'] = df_ruten_vest2
df_ruten_clothes['short1'] = df_ruten_short1
df_ruten_clothes['short2'] = df_ruten_short2
df_ruten_clothes['shorts1'] = df_ruten_shorts1
df_ruten_clothes['shorts2'] = df_ruten_shorts2

df_ruten_clothes1 = {}
df_ruten_clothes1['coat1'] = df_ruten_coat1[0:100]
df_ruten_clothes1['coat2'] = df_ruten_coat2[0:100]
df_ruten_clothes1['long1'] = df_ruten_long1[0:100]
df_ruten_clothes1['long2'] = df_ruten_long2[0:100]
df_ruten_clothes1['pants1'] = df_ruten_pants1[0:100]
df_ruten_clothes1['pants2'] = df_ruten_pants2[0:100]
df_ruten_clothes1['vest1'] = df_ruten_vest1[0:100]
df_ruten_clothes1['vest2'] = df_ruten_vest2[0:100]
df_ruten_clothes1['short1'] = df_ruten_short1[0:100]
df_ruten_clothes1['short2'] = df_ruten_short2[0:100]
df_ruten_clothes1['shorts1'] = df_ruten_shorts1[0:100]
df_ruten_clothes1['shorts2'] = df_ruten_shorts2[0:100]

# %%
df_shopee_coat1 = pd.read_csv('clothes_shopee/shopee外套女.csv',index_col=0)
df_shopee_coat2 = pd.read_csv('clothes_shopee/shopee外套男.csv',index_col=0)
df_shopee_long1 = pd.read_csv('clothes_shopee/shopee長袖女.csv',index_col=0)
df_shopee_long2 = pd.read_csv('clothes_shopee/shopee長袖男.csv',index_col=0)
df_shopee_pants1 = pd.read_csv('clothes_shopee/shopee長褲女.csv',index_col=0)
df_shopee_pants2 = pd.read_csv('clothes_shopee/shopee長褲男.csv',index_col=0)
df_shopee_vest1 = pd.read_csv('clothes_shopee/shopee背心女.csv',index_col=0)
df_shopee_vest2 = pd.read_csv('clothes_shopee/shopee背心男.csv',index_col=0)
df_shopee_short1 = pd.read_csv('clothes_shopee/shopee短袖女.csv',index_col=0)
df_shopee_short2 = pd.read_csv('clothes_shopee/shopee短袖男.csv',index_col=0)
df_shopee_shorts1 = pd.read_csv('clothes_shopee/shopee短褲女.csv',index_col=0)
df_shopee_shorts2 = pd.read_csv('clothes_shopee/shopee短褲男.csv',index_col=0)
df_shopee_clothes = {}
df_shopee_clothes['coat1'] = df_shopee_coat1
df_shopee_clothes['coat2'] = df_shopee_coat2
df_shopee_clothes['long1'] = df_shopee_long1
df_shopee_clothes['long2'] = df_shopee_long2
df_shopee_clothes['pants1'] = df_shopee_pants1
df_shopee_clothes['pants2'] = df_shopee_pants2
df_shopee_clothes['vest1'] = df_shopee_vest1
df_shopee_clothes['vest2'] = df_shopee_vest2
df_shopee_clothes['short1'] = df_shopee_short1
df_shopee_clothes['short2'] = df_shopee_short2
df_shopee_clothes['shorts1'] = df_shopee_shorts1
df_shopee_clothes['shorts2'] = df_shopee_shorts2

df_shopee_clothes1 = {}
df_shopee_clothes1['coat1'] = df_shopee_coat1[0:100]
df_shopee_clothes1['coat2'] = df_shopee_coat2[0:100]
df_shopee_clothes1['long1'] = df_shopee_long1[0:100]
df_shopee_clothes1['long2'] = df_shopee_long2[0:100]
df_shopee_clothes1['pants1'] = df_shopee_pants1[0:100]
df_shopee_clothes1['pants2'] = df_shopee_pants2[0:100]
df_shopee_clothes1['vest1'] = df_shopee_vest1[0:100]
df_shopee_clothes1['vest2'] = df_shopee_vest2[0:100]
df_shopee_clothes1['short1'] = df_shopee_short1[0:100]
df_shopee_clothes1['short2'] = df_shopee_short2[0:100]
df_shopee_clothes1['shorts1'] = df_shopee_shorts1[0:100]
df_shopee_clothes1['shorts2'] = df_shopee_shorts2[0:100]

# %%
df_shopee_watch = pd.read_csv('配件_shopee/shopee手錶.csv',index_col=0)
df_shopee_belt = pd.read_csv('配件_shopee/shopee皮帶.csv',index_col=0)
df_shopee_ear = pd.read_csv('配件_shopee/shopee耳環.csv',index_col=0)
df_shopee_bag = pd.read_csv('配件_shopee/shopee背包.csv',index_col=0)
df_shopee_glasses = pd.read_csv('配件_shopee/shopee眼鏡.csv',index_col=0)
df_shopee_hat = pd.read_csv('配件_shopee/shopee帽子.csv',index_col=0)
df_shopee_neck = pd.read_csv('配件_shopee/shopee項鍊.csv',index_col=0)
df_shopee_pocket = pd.read_csv('配件_shopee/shopee錢包.csv',index_col=0)
df_shopee_socks = pd.read_csv('配件_shopee/shopee襪子.csv',index_col=0)
df_shopee_acce = {}
df_shopee_acce['watch'] = df_shopee_watch
df_shopee_acce['belt'] = df_shopee_belt
df_shopee_acce['ear'] = df_shopee_ear
df_shopee_acce['bag'] = df_shopee_bag
df_shopee_acce['glasses'] = df_shopee_glasses
df_shopee_acce['hat'] = df_shopee_hat
df_shopee_acce['neck'] = df_shopee_neck
df_shopee_acce['pocket'] = df_shopee_pocket
df_shopee_acce['socks'] = df_shopee_socks

df_shopee_acce1 = {}
df_shopee_acce1['watch'] = df_shopee_watch[0:100]
df_shopee_acce1['belt'] = df_shopee_belt[0:100]
df_shopee_acce1['ear'] = df_shopee_ear[0:100]
df_shopee_acce1['bag'] = df_shopee_bag[0:100]
df_shopee_acce1['glasses'] = df_shopee_glasses[0:100]
df_shopee_acce1['hat'] = df_shopee_hat[0:100]
df_shopee_acce1['neck'] = df_shopee_neck[0:100]
df_shopee_acce1['pocket'] = df_shopee_pocket[0:100]
df_shopee_acce1['socks'] = df_shopee_socks[0:100]

# %%
df_ruten_watch = pd.read_csv('配件_ruten/露天_手錶.csv',index_col=0)
df_ruten_belt = pd.read_csv('配件_ruten/露天_皮帶.csv',index_col=0)
df_ruten_ear = pd.read_csv('配件_ruten/露天_耳環.csv',index_col=0)
df_ruten_bag = pd.read_csv('配件_ruten/露天_背包.csv',index_col=0)
df_ruten_glasses = pd.read_csv('配件_ruten/露天_眼鏡.csv',index_col=0)
df_ruten_hat = pd.read_csv('配件_ruten/露天_帽子.csv',index_col=0)
df_ruten_neck = pd.read_csv('配件_ruten/露天_項鍊.csv',index_col=0)
df_ruten_pocket = pd.read_csv('配件_ruten/露天_錢包.csv',index_col=0)
df_ruten_socks = pd.read_csv('配件_ruten/露天_襪子.csv',index_col=0)
df_ruten_acce = {}
df_ruten_acce['watch'] = df_ruten_watch
df_ruten_acce['belt'] = df_ruten_belt
df_ruten_acce['ear'] = df_ruten_ear
df_ruten_acce['bag'] = df_ruten_bag
df_ruten_acce['glasses'] = df_ruten_glasses
df_ruten_acce['hat'] = df_ruten_hat
df_ruten_acce['neck'] = df_ruten_neck
df_ruten_acce['pocket'] = df_ruten_pocket
df_ruten_acce['socks'] = df_ruten_socks

df_ruten_acce1 = {}
df_ruten_acce1['watch'] = df_ruten_watch[0:100]
df_ruten_acce1['belt'] = df_ruten_belt[0:100]
df_ruten_acce1['ear'] = df_ruten_ear[0:100]
df_ruten_acce1['bag'] = df_ruten_bag[0:100]
df_ruten_acce1['glasses'] = df_ruten_glasses[0:100]
df_ruten_acce1['hat'] = df_ruten_hat[0:100]
df_ruten_acce1['neck'] = df_ruten_neck[0:100]
df_ruten_acce1['pocket'] = df_ruten_pocket[0:100]
df_ruten_acce1['socks'] = df_ruten_socks[0:100]

# %%
def get_TF(words, topK=10): 
    tf_dic = {} 
    for w in words: 
        tf_dic[w] = tf_dic.get(w, 0) + 1 
    return sorted(tf_dic.items(), key = lambda x: x[1], reverse=True)[:topK]

# %%
def get_content(path):
    with open(path, 'r', encoding='utf-8', errors='ignore') as f: 
        content = '' 
        for l in f:
            l = l.strip() 
            content += l 
    return content

# %%
stop_words = []
stop_words.append(' ')
stop_words.append('【')
stop_words.append('】')
stop_words.append('-')
stop_words.append('.')
stop_words.append('Ω')
stop_words.append('》')
stop_words.append('☆')
stop_words.append('(')
stop_words.append('/')
stop_words.append('+')
stop_words.append('?')
stop_words.append('*')
stop_words.append('《')
stop_words.append(')')
stop_words.append('~')
stop_words.append('★')
stop_words.append('_')
stop_words.append(',')
stop_words.append('、')
stop_words.append('＊')
stop_words.append('[')
stop_words.append(']')
stop_words.append('&')
stop_words.append('♥')

# %%
#將csv data存到txt
split_words = {}
st = {}
for item in df_ruten_elec:
    s = str(item)
    files = 'ruten.txt'
    f = open(files,'w')
    for item1 in df_ruten_elec[item]['item']:
        print(item1, file = f)
    f.close()
    corpus = [get_content(files)]
    split_words[s] = [x for x in jieba.cut(corpus[0]) if x not in stop_words]
    st[s] = get_TF(split_words[s],10)
#     print(s + '的topK(10)詞：'+str(get_TF(split_words[s],10)))
    print(st[s])
print("top100")
split = {}
st1 = {}
for item in df_ruten_elec1:
    s = str(item)
    files = 'ruten.txt'
    f = open(files,'w')
    for item1 in df_ruten_elec1[item]['item']:
        print(item1, file = f)
    f.close()
    corpus = [get_content(files)]
    split[s] = [x for x in jieba.cut(corpus[0]) if x not in stop_words]
    st1[s] = get_TF(split[s],10)
#     print(s + '的topK(10)詞：'+str(get_TF(split[s],10)))
    print(st1[s])
# Out:
# [('吸塵器', 6431), ('無線', 851), ('配件', 612), ('兩用', 611), ('吸頭', 606), ('手持', 595), ('車用', 554), ('濾網', 522), ('專用', 517), ('集塵袋', 469)]
# [('果汁', 1375), ('機', 1370), ('榨汁', 456), ('杯', 255), ('調理機', 174), ('隨行杯', 130), ('迷你', 108), ('電動', 105), ('隨身', 102), ('現貨', 100)]
# [('氣炸鍋', 864), ('油瓶', 286), ('配件', 225), ('炸鍋', 188), ('噴', 156), ('紙', 152), ('現貨', 149), ('烘焙', 139), ('噴霧', 133), ('不', 131)]
# [('烤箱', 2680), ('爐', 611), ('烘焙', 568), ('烤', 563), ('手套', 548), ('微波', 533), ('不', 435), ('廚房', 388), ('蛋糕', 336), ('麵', 329)]
# [('飲水機', 3046), ('水器', 2798), ('淨', 1316), ('RO', 1282), ('淨水', 1028), ('貨號', 942), ('純水機', 769), ('濾心', 733), ('濾', 677), ('過濾器', 671)]
# [('微波', 2411), ('爐', 1502), ('架', 588), ('手套', 502), ('烤箱', 379), ('廚房', 373), ('爐架', 281), ('置物架', 276), ('收納架', 253), ('電器', 250)]
# [('風扇', 5690), ('電風扇', 4832), ('扇', 4346), ('吋', 2586), ('電扇', 2120), ('USB', 1460), ('迷你', 1143), ('製', 1082), ('灣', 946), ('台', 940)]
# ...

# %%
s = []
for item in st:
    s1 = ''
    for i in range(10):
        for j in range(10):
            if st[item][i][0] == st1[item][j][0]:
                s1+=st[item][i][0]
    s.append((item, s1))
print(s)
# Out:
# [('dust', '吸塵器無線兩用手持車用集塵袋'), ('juice', '果汁機榨汁杯調理機隨身現貨'), ('fry', '氣炸鍋油瓶配件炸鍋噴紙現貨烘焙'), ('oven', '烤箱爐烘焙烤手套微波不廚房麵'), ('water', '飲水機水器淨RO淨水貨號純水機濾心'), ('wave', '微波爐手套烤箱廚房'), ('wind', '風扇電風扇扇吋電扇USB迷你'), ('stove', '電磁爐鍋不爐'), ('pot', '電鍋人份不大同製10'), ('weight', '秤體重計重計電子體重電池')]

# %%
#將csv data存到txt
split_words1 = {}
st = {}
for item in df_ruten_clothes:
    s = str(item)
    files = 'ruten.txt'
    f = open(files,'w')
    for item1 in df_ruten_clothes[item]['item']:
        print(item1, file = f)
    f.close()
    corpus = [get_content(files)]
    split_words1[s] = [x for x in jieba.cut(corpus[0]) if x not in stop_words]
    st[s] = get_TF(split_words1[s],10)
    print(st[s])
#     print(s + '的topK(10)詞：',get_TF(split_words1[s],10))
    
print("top100")

split1 = {}
st1 = {}
for item in df_ruten_clothes1:
    s = str(item)
    files = 'ruten.txt'
    f = open(files,'w')
    for item1 in df_ruten_clothes1[item]['item']:
        print(item1, file = f)
    f.close()
    corpus = [get_content(files)]
    split1[s] = [x for x in jieba.cut(corpus[0]) if x not in stop_words]
    st1[s] = get_TF(split1[s],10)
    print(st1[s])
#     print(s + '的topK(10)詞：',get_TF(split1[s],10))
# Out:
# [('外套', 5924), ('男女', 1353), ('連帽', 1042), ('女', 657), ('風衣', 614), ('款', 604), ('新款', 598), ('長', 541), ('夾克', 541), ('韓版', 515)]
# [('外套', 11270), ('男', 2733), ('夾克', 1847), ('連帽', 1679), ('男女', 1391), ('風衣', 1330), ('休閒', 1321), ('男士', 1283), ('韓版', 1123), ('修身', 1010)]
# [('袖', 3695), ('長', 3268), ('男女', 1279), ('上衣', 1248), ('T恤', 1171), ('T', 1087), ('外套', 749), ('襯衫', 737), ('新款', 710), ('衣服', 683)]
# [('袖', 5225), ('長', 4641), ('襯衫', 2357), ('T恤', 2354), ('男', 2228), ('T', 2130), ('運動', 1436), ('衣服', 1293), ('男女', 1244), ('上衣', 1199)]
# [('褲', 3642), ('長', 1039), ('男女', 606), ('褲子', 434), ('運動', 366), ('慢跑', 355), ('愛迪達', 283), ('緊身', 281), ('健身', 266), ('運動褲', 265)]
# [('褲', 8017), ('長', 2363), ('男', 1385), ('褲子', 956), ('牛仔', 937), ('運動', 705), ('男女', 673), ('休閒褲', 647), ('男士', 605), ('修身', 598)]
# [('背心', 2190), ('內衣', 539), ('運動', 332), ('女', 317), ('男女', 285), ('女童', 253), ('上衣', 242), ('裙', 235), ('無袖', 231), ('內', 219)]
# ...

# %%
s = []
for item in st:
    s1 = ''
    for i in range(10):
        for j in range(10):
            if st[item][i][0] == st1[item][j][0]:
                s1+=st[item][i][0]
    s.append((item, s1))
print(s)
# Out:
# [('coat1', '外套男女連帽女'), ('coat2', '外套男夾克連帽男女韓版修身'), ('long1', '袖長男女上衣T襯衫'), ('long2', '袖長襯衫T恤男T男女'), ('pants1', '褲長男女慢跑緊身運動褲'), ('pants2', '褲長男牛仔休閒褲修身'), ('vest1', '背心內衣運動女男女內'), ('vest2', '背心男運動無袖'), ('short1', '短袖T恤男女T上衣短'), ('short2', '短袖T恤T男女上衣衫運動'), ('shorts1', '短褲褲運動男女休閒鬆'), ('shorts2', '短褲褲五分運動男休閒健身')]

# %%
#將csv data存到txt
split_words2 = {}
for item in df_ruten_acce:
    s = str(item)
    files = 'ruten.txt'
    f = open(files,'w')
    for item1 in df_ruten_acce[item]['item']:
        print(item1, file = f)
    f.close()
    corpus = [get_content(files)]
    split_words2[s] = [x for x in jieba.cut(corpus[0]) if x not in stop_words]
    print(s + '的topK(10)詞：'+str(get_TF(split_words2[s],11)))
    
print("top100")

split2 = {}
for item in df_ruten_acce1:
    s = str(item)
    files = 'ruten.txt'
    f = open(files,'w')
    for item1 in df_ruten_acce1[item]['item']:
        print(item1, file = f)
    f.close()
    corpus = [get_content(files)]
    split2[s] = [x for x in jieba.cut(corpus[0]) if x not in stop_words]
    print(s + '的topK(10)詞：'+str(get_TF(split2[s],11)))
# Out:
# watch的topK(10)詞：[('錶', 18055), ('手', 7598), ('帶', 2534), ('防水', 1320), ('妖怪', 1284), ('電池', 1096), ('手環', 1030), ('男', 918), ('CASIO', 868), ('電子', 820), ('工具', 783)]
# belt的topK(10)詞：[('皮帶', 8001), ('帶', 3565), ('腰', 1337), ('錶', 1065), ('扣', 993), ('腰帶', 982), ('原廠', 843), ('皮', 830), ('製', 679), ('真皮', 637), ('牛皮', 590)]
# ear的topK(10)詞：[('耳環', 5386), ('耳洞', 1381), ('韓國', 1377), ('鈦', 1352), ('耳', 1347), ('鋼', 1238), ('款', 1147), ('鍊', 1009), ('無', 992), ('鑽', 868), ('◆', 783)]
# bag的topK(10)詞：[('背包', 12469), ('包', 4375), ('後', 2981), ('側', 1704), ('斜', 1494), ('防水', 1344), ('扣', 1071), ('現貨', 935), ('腰包', 864), ('登山', 782), ('手提包', 752)]
# glasses的topK(10)詞：[('眼鏡', 11300), ('太陽', 2210), ('偏光', 1507), ('盒', 974), ('!', 880), ('鏡片', 822), ('鏡', 822), ('可', 792), ('運動', 783), ('鼻墊', 692), ('墨鏡', 638)]
# hat的topK(10)詞：[('帽子', 7776), ('帽', 2962), ('棒球帽', 1288), ('鴨舌帽', 905), ('遮陽帽', 803), ('保暖', 709), ('現貨', 679), ('男女', 614), ('韓版', 520), ('髮', 518), ('毛線', 475)]
# ...

# %%
#將csv data存到txt
split_words3 = {}
for item in df_shopee_elec:
    s = str(item)
    files = 'ruten.txt'
    f = open(files,'w')
    for item1 in df_shopee_elec[item]['item']:
        print(item1, file = f)
    f.close()
    corpus = [get_content(files)]
    split_words3[s] = [x for x in jieba.cut(corpus[0]) if x not in stop_words]
    print(s + '的topK(10)詞：'+str(get_TF(split_words3[s],10)))
    
print("top100")

split3 = {}
for item in df_shopee_elec1:
    s = str(item)
    files = 'ruten.txt'
    f = open(files,'w')
    for item1 in df_shopee_elec1[item]['item']:
        print(item1, file = f)
    f.close()
    corpus = [get_content(files)]
    split3[s] = [x for x in jieba.cut(corpus[0]) if x not in stop_words]
    print(s + '的topK(10)詞：'+str(get_TF(split3[s],10)))
# Out:
# dust的topK(10)詞：[('吸塵器', 2754), ('無線', 660), ('手持', 512), ('現貨', 389), ('車用', 345), ('兩用', 329), ('優選', 261), ('濾網', 232), ('小米', 217), ('除', 214)]
# juice的topK(10)詞：[('機', 1599), ('果汁', 1253), ('榨汁', 962), ('杯', 501), ('隨行杯', 232), ('電動', 220), ('迷你', 210), ('現貨', 196), ('優選', 191), ('隨身', 189)]
# fry的topK(10)詞：[('氣炸鍋', 432), ('炸鍋', 152), ('現貨', 135), ('台灣', 96), ('L', 89), ('保固', 80), ('健康', 77), ('專用', 70), ('科帥', 66), ('免運', 65)]
# oven的topK(10)詞：[('烤箱', 497), ('烘焙', 91), ('墊', 75), ('烤', 75), ('麵', 67), ('現貨', 62), ('優選', 56), ('爐', 51), ('公升', 49), ('蝦皮', 46)]
# water的topK(10)詞：[('飲水機', 585), ('寵物', 301), ('水器', 192), ('飲', 112), ('機', 99), ('優選', 97), ('自動', 90), ('智能', 85), ('活水', 84), ('現貨', 83)]
# wave的topK(10)詞：[('微波', 176), ('爐', 136), ('NN', 37), ('Panasonic', 29), ('國際牌', 28), ('公升', 23), ('日本', 22), ('蓋', 19), ('微電腦', 19), ('20L', 15)]
# ...

# %%
#將csv data存到txt
split_words4 = {}
st = {}
for item in df_shopee_clothes:
    s = str(item)
    files = 'ruten.txt'
    f = open(files,'w')
    for item1 in df_shopee_clothes[item]['item']:
        print(item1, file = f)
    f.close()
    corpus = [get_content(files)]
    split_words4[s] = [x for x in jieba.cut(corpus[0]) if x not in stop_words]
    st[s] = get_TF(split_words4[s],10)
    print(st[s])
#     print(s + '的topK(10)詞：'+str(get_TF(split_words4[s],10)))
    
print("top100")

split4 = {}
st1 = {}
for item in df_shopee_clothes1:
    s = str(item)
    files = 'ruten.txt'
    f = open(files,'w')
    for item1 in df_shopee_clothes1[item]['item']:
        print(item1, file = f)
    f.close()
    corpus = [get_content(files)]
    split4[s] = [x for x in jieba.cut(corpus[0]) if x not in stop_words]
    st1[s] = get_TF(split4[s],10)
    print(st1[s])
#     print(s + '的topK(10)詞：'+str(get_TF(split4[s],10)))
# Out:
# [('外套', 4868), ('女', 1909), ('新款', 1267), ('韓版', 1199), ('上衣', 1176), ('袖', 996), ('寬', 881), ('襯衫', 797), ('長', 742), ('牛仔', 719)]
# [('外套', 3284), ('男', 1487), ('襯衫', 861), ('韓版', 541), ('夾克', 513), ('袖', 421), ('潮流', 398), ('連帽', 392), ('休閒', 359), ('現貨', 335)]
# [('袖', 2843), ('上衣', 2340), ('襯衫', 2329), ('女', 2233), ('長', 2042), ('新款', 1476), ('外套', 1241), ('韓版', 1189), ('寬', 928), ('衫', 879)]
# [('襯衫', 1875), ('袖', 1396), ('男', 1133), ('長', 966), ('外套', 626), ('韓版', 482), ('上衣', 458), ('襯衣', 417), ('男士', 341), ('潮流', 337)]
# [('褲', 6268), ('褲女', 2068), ('牛仔', 2013), ('長', 1648), ('新款', 1237), ('九分', 1237), ('寬', 1212), ('高腰', 1121), ('鬆', 1105), ('女', 929)]
# [('褲', 7917), ('男', 2693), ('牛仔', 2069), ('長', 1627), ('褲子', 1223), ('九分', 1068), ('韓版', 868), ('寬', 848), ('男生', 840), ('潮流', 829)]
# [('背心', 5044), ('女', 2014), ('吊帶', 1674), ('上衣', 1584), ('打底', 1331), ('內衣', 1120), ('運動', 935), ('無袖', 926), ('性感', 900), ('搭', 826)]
# ...

# %%
s = []
for item in st:
    s1 = ''
    for i in range(10):
        for j in range(10):
            if st[item][i][0] == st1[item][j][0]:
                s1+=st[item][i][0]
    s.append((item, s1))
print(s)
# Out:
# [('coat1', '外套女韓版上衣袖寬襯衫長牛仔'), ('coat2', '外套男襯衫韓版夾克連帽休閒'), ('long1', '袖上衣襯衫女長新款外套韓版寬衫'), ('long2', '襯衫袖男長外套韓版襯衣男士'), ('pants1', '褲褲女牛仔長新款九分寬高腰鬆女'), ('pants2', '褲男牛仔長褲子九分寬男生'), ('vest1', '背心女吊帶上衣打底內衣運動無袖'), ('vest2', '背心男運動無袖健身'), ('short1', '短袖上衣女T恤夏季韓版t寬鬆'), ('short2', '短袖男T恤上衣夏季T襯衫'), ('shorts1', '短褲褲女牛仔夏季寬高腰鬆'), ('shorts2', '短褲褲男五分休閒夏季運動牛仔鬆')]

# %%
#將csv data存到txt
split_words5 = {}
for item in df_shopee_acce:
    s = str(item)
    files = 'ruten.txt'
    f = open(files,'w')
    for item1 in df_shopee_acce[item]['item']:
        print(item1, file = f)
    f.close()
    corpus = [get_content(files)]
    split_words5[s] = [x for x in jieba.cut(corpus[0]) if x not in stop_words]
    print(s + '的topK(10)詞：'+str(get_TF(split_words5[s],10)))
    
print("top100")

split5 = {}
for item in df_shopee_acce1:
    s = str(item)
    files = 'ruten.txt'
    f = open(files,'w')
    for item1 in df_shopee_acce1[item]['item']:
        print(item1, file = f)
    f.close()
    corpus = [get_content(files)]
    split5[s] = [x for x in jieba.cut(corpus[0]) if x not in stop_words]
    print(s + '的topK(10)詞：'+str(get_TF(split5[s],10)))
# Out:
# watch的topK(10)詞：[('錶', 9128), ('手', 3389), ('防水', 938), ('現貨', 791), ('手環', 683), ('電子', 638), ('石英', 607), ('兒童', 548), ('運動', 495), ('優選', 493)]
# belt的topK(10)詞：[('皮帶', 4105), ('帶', 3099), ('腰', 1473), ('腰帶', 1155), ('現貨', 814), ('皮', 642), ('錶', 579), ('真皮', 555), ('優選', 538), ('男士', 529)]
# ear的topK(10)詞：[('耳環', 3395), ('優選', 1345), ('耳', 1340), ('皮', 907), ('蝦', 817), ('韓國', 789), ('現貨', 770), ('銀針', 706), ('耳夾', 695), ('簡約', 673)]
# bag的topK(10)詞：[('背包', 6485), ('後', 2006), ('包', 1932), ('現貨', 1114), ('防水', 791), ('書包', 777), ('優選', 716), ('雙肩包', 673), ('大容量', 570), ('包包', 487)]
# glasses的topK(10)詞：[('眼鏡', 6380), ('太陽', 1605), ('墨鏡', 1412), ('復', 999), ('現貨', 966), ('優選', 949), ('偏光', 804), ('皮', 676), ('鏡', 624), ('蝦', 595)]
# hat的topK(10)詞：[('帽子', 2172), ('帽', 2002), ('現貨', 1315), ('漁夫帽', 1213), ('遮陽帽', 1098), ('棒球帽', 1087), ('鴨舌帽', 768), ('優選', 702), ('老帽', 652), ('韓版', 560)]
# ...

# %%
print('樣本的topK(100)詞：'+str(get_TF(split_words,10)))
# Out:
# 樣本的topK(100)詞：[('秤', 325), ('體重計', 302), ('重計', 293), ('電子', 169), ('電子體', 165), ('體重', 154), ('玻璃', 140), ('電池', 124), ('體重機', 102), ('小米', 79)]

# %%
#learning
frequent_array = get_TF(split_words,100)
score = [0]*len(df_shopee['item'])
index = 0
for item in df_shopee['item']:
    for i in range(len(frequent_array)):
        if (frequent_array[i][0]) in item:
            score[index] += frequent_array[i][1]
    index += 1
df_shopee['item'] = score

# %%
price_array = df_shopee['price']
price_array_2 = ['0'] * len(price_array)
index_i = 0
for item in price_array:
    if('-' in item):
        index_j = str.index(item,'-')
        price_array_2[index_i] = item[-index_j:]
    else:
        price_array_2[index_i] = item
    index_i += 1
index_i = 0
for item in price_array_2:
    price_array_2[index_i] = str.replace(item,"$","")
    item = price_array_2[index_i]
    price_array_2[index_i] = float(str.replace(item,",",""))
    index_i += 1
df_shopee['price'] = price_array_2

# %%
df_shopee = df_shopee.drop(df_shopee[df_shopee.price>2000].index)

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
sc.fit(df_shopee)
df_shopee = pd.DataFrame(sc.transform(df_shopee), index=df_shopee.index, columns=df_shopee.columns)
# Out:
# /Users/kuohuichi/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
df_shopee
# Out:
#           item      rate  num_product  num_sold     price
# 0     0.619289  0.069403     0.000015  1.000000  0.149575
# 1     0.661478  0.069396     0.000015  0.603158  0.149575
# 2     0.627211  0.093900     0.000204  0.492152  0.064532
# 3     0.864683  0.001460     0.000597  0.443933  0.194597
# 4     0.847273  0.001460     0.000597  0.398440  0.194597
# ...        ...       ...          ...       ...       ...
# 2448  0.550387  0.005027     0.004160  0.000000  0.318659
# 2449  0.597273  0.018323     0.000505  0.000000  0.419210
# 2450  0.787675  0.037069     0.005609  0.000000  0.584792
# 2451  0.635777  0.008296     0.002010  0.000000  0.274637
# 2452  0.656411  0.015423     0.000478  0.000000  0.049525
#
# [2404 rows x 5 columns]

# %%
from sklearn.utils import shuffle
df = shuffle(df_shopee)

# %%
df
# Out:
#           item      rate  num_product  num_sold     price
# 1455  0.696389  0.000160     0.035652  0.000000  0.269635
# 2027  0.673452  0.022801     0.001999  0.000000  0.493247
# 2169  0.688928  0.002865     0.000118  0.000000  0.224612
# 2050  0.538412  0.003957     0.001047  0.000000  0.083542
# 39    0.688836  0.010861     0.000329  0.094182  0.074037
# ...        ...       ...          ...       ...       ...
# 1572  0.633935  0.080863     0.000304  0.000094  0.449725
# 1476  0.683677  0.000021     0.009197  0.000000  0.184092
# 386   0.750829  0.059738     0.002293  0.004136  0.217109
# 535   0.837693  0.001453     0.000585  0.002444  0.197099
# 881   0.671518  0.031604     0.000409  0.000564  0.052026
#
# [2404 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(columns = ['num_sold']).values[0:2000],
    df['num_sold'].values[0:2000], test_size=0.5)
X_ans = df.drop(columns = ['num_sold']).values[2000:]

# %%
import xgboost
params = {}
params['objective'] = 'binary:logistic'
params['eval_metric'] = 'logloss'
params['eta'] = 0.04
params['max_depth'] = 8
params['learning_rate'] = 0.01

d_train = xgboost.DMatrix(X_train, label=y_train)
d_valid = xgboost.DMatrix(X_test, label=y_test)

watchlist = [(d_train, 'train'), (d_valid, 'valid')]

bst = xgboost.train(params, d_train, 1000, watchlist, early_stopping_rounds=100, verbose_eval=10)
y_pred = bst.predict(xgboost.DMatrix(X_test))
# Out:
# [0]	train-logloss:0.683488	valid-logloss:0.683519
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 100 rounds.
# [10]	train-logloss:0.596529	valid-logloss:0.596854
# [20]	train-logloss:0.524111	valid-logloss:0.524705
# [30]	train-logloss:0.463011	valid-logloss:0.463857
# [40]	train-logloss:0.410931	valid-logloss:0.412014
# [50]	train-logloss:0.366179	valid-logloss:0.367487
# [60]	train-logloss:0.327467	valid-logloss:0.32899
# [70]	train-logloss:0.293798	valid-logloss:0.295529
# [80]	train-logloss:0.264384	valid-logloss:0.266314
# [90]	train-logloss:0.238581	valid-logloss:0.240692
# [100]	train-logloss:0.215838	valid-logloss:0.218083
# [110]	train-logloss:0.195763	valid-logloss:0.198152
# [120]	train-logloss:0.178003	valid-logloss:0.180545
# [130]	train-logloss:0.16226	valid-logloss:0.164961
# [140]	train-logloss:0.148282	valid-logloss:0.151149
# ...

# %%
ans_pred = bst.predict(xgboost.DMatrix(X_ans))

# %%
answer = df['num_sold'].values[2000:]
count = 0 
for i in range(len(answer)):
        if(abs(answer[i]-ans_pred[i])<=0.005):
            count += 1
a = len(df['num_sold'][2000:])
print(count/a)
# Out:
# 0.7524752475247525

# %%
ans_pred
# Out:
# array([0.00331365, 0.00141234, 0.01257212, 0.00157202, 0.01206048,
#        0.00102284, 0.0012239 , 0.04160026, 0.00540437, 0.00121941,
#        0.00421609, 0.00157202, 0.00220876, 0.02359403, 0.00121354,
#        0.00780478, 0.01326688, 0.00139441, 0.00141234, 0.0032554 ,
#        0.01599027, 0.0012239 , 0.00286149, 0.00102284, 0.00857058,
#        0.0057774 , 0.00121941, 0.0014921 , 0.00702417, 0.00398222,
#        0.0057774 , 0.00102284, 0.0203107 , 0.00246302, 0.0033051 ,
#        0.00180912, 0.00121941, 0.00385423, 0.0317959 , 0.00761137,
#        0.00118543, 0.00208443, 0.00173346, 0.00519414, 0.00709643,
#        0.00614052, 0.00329403, 0.01049868, 0.00208443, 0.00198721,
#        0.00404073, 0.00101508, 0.0057774 , 0.01379973, 0.00740282,
#        0.01644477, 0.00095204, 0.00150449, 0.00126144, 0.0012239 ,
#        0.00135199, 0.00316126, 0.01358676, 0.00095204, 0.00096079,
#        0.00176559, 0.0018597 , 0.00227062, 0.00166581, 0.00262713,
# ...
